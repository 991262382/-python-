# %%
f = open('test','r')
f.read()
f.close()
# Out:
# '这是一个测试\ntest1\ntest2\ntest3\ntest4'

# %%
with open('test','r') as f:
   for line in f.readlines():
       print(line)
# Out:
# 这是一个测试
#
# test1
#
# test2
#
# test3
#
# test4

# %%
with open('朱洋洋.JPG','rb') as f:
    for line in f.readlines():
       print(line)
# 十六进制表示的字节
# Out:
# b"\xff\xd8\xff\xe1\x13>Exif\x00\x00II*\x00\x08\x00\x00\x00\x10\x00\x00\x01\x03\x00\x01\x00\x00\x00@\x10\x00\x00\x01\x01\x03\x00\x01\x00\x00\x00`(\x01\x03\x00\x01\x00\x00\x00\x02\x00\x00\x001\x01\x02\x00\x1c\x00\x00\x00\xff\x00\x00\x002\x01\x02\x00\x14\x00\x00\x00\x1b\x01\x00\x00\x13\x02\x03\x00\x01\x00\x00\x00\x02\x00\x00\x00i\x87\x04\x00\x01\x00\x00\x000\x01\x00\x00%\x88\x04\x00\x01\x00\x00\x00\x00\x05\x00\x00\x14\x05\x00\x00\x08\x00\x08\x00\x08\x00Canon\x00Canon EOS 6D Mark II\x00\xc0\xc6-\x00\x10'\x00\x00\xc0\xc6-\x00\x10'\x00\x00Adobe Photoshop CS5 Windows\x002019:07:02 16:02:48\x00\x00'\x00
# ...

# %%
with open('test2.txt','w') as f:
    f.write('fuck')
# Out:
# 4

# %%
from io import BytesIO
f = BytesIO()
f.write('中文'.encode('utf8'))
# Out:
# 6

# %%
print(f.getvalue())
# Out:
# b'\xe4\xb8\xad\xe6\x96\x87'
